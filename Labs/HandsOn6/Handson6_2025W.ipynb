# %% [markdown]
# # Hands-on 6
#
# ### CS2545 - Data Science ###
# ### Winter, 2025 ###
# ### UNB, Fredericton ###
#
# Please complete the following tasks per instructions provided. Submission is not necessary for this handson, but attendance will be taken at the end of the class.
# </br>
# </br>

# %% [markdown]
#  **Q1** For this handson you will further analyze a dataset that contains nutrition information about many common food items.
#
# Download the data file *food_group_nutrition.csv* from D2L, and then load the data  into a dataframe. This dataset contains  nutrition information about different food items. Also download the two .py files.
#
# Load the data into a suitable dataframe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import thinkstats2
import thinkplot

# Q1 write your code below
foodGroups = pd.read_csv('food_group_nutrition.csv')
foodGroupsDF = pd.DataFrame(foodGroups)
foodGroupsDF
# Out:
#           Category      Food_group  \
# 0           BUTTER           Dairy
# 1           BUTTER           Dairy
# 2       BUTTER OIL           Dairy
# 3           CHEESE           Dairy
# 4           CHEESE           Dairy
# ...            ...             ...
# 5803      FRYBREAD             NaN
# 5804   No Category             NaN
# 5805  TENNIS BREAD             NaN
# 5806          FISH  Protein-animal
# 5807        SALMON  Protein-animal
#
#                                        Item_Description  Item_Number  \
# 0                                      BUTTER,WITH SALT         1001
# 1                              BUTTER,WHIPPED,WITH SALT         1002
# 2                                  BUTTER OIL,ANHYDROUS         1003
# 3                                           CHEESE,BLUE         1004
# 4                                          CHEESE,BRICK         1005
# ...                                                 ...          ...
# ...

# %% [markdown]
# **Q2**
#
# Q2.1) Using *thinkstats2* and *thinkplot* APIs, plot the Probability mass functions (Pmf) of the *Protein* for two food groups: <br>
# i) Protein-plant <br>
# ii) Protein-animal <br>
#
#
# Q2.2) Using *thinkstats2* and *thinkplot* APIs, plot the Probability mass functions (Pmf) of the *Fiber* for two food groups: <br>
# i) Protein-plant <br>
# ii) Protein-animal <br>

# %%
#Q2.1 write your code here
plantProtein = foodGroupsDF[foodGroupsDF['Food_group'] == 'Protein-plant']
plantProteinList = plantProtein['Protein'].tolist()

animalProtein = foodGroupsDF[foodGroupsDF['Food_group'] == 'Protein-animal']
animalProteinList = animalProtein['Protein'].tolist()


pmfPlant = thinkstats2.Pmf(plantProteinList)
thinkplot.Pmf(pmfPlant)
thinkplot.Show()
# pmfAnimal = thinkstats2.Pmf(animalProteinList)
# pmfAnimal


# plantProtein[['Fiber']]

# animalProtein = foodGroupsDF[foodGroupsDF['Food_group'] == 'Protein-animal']
# animalProtein[animalProtein['Protein']]
# animalProtein[animalProtein['Fiber']]
# Out:
# No handles with labels found to put in legend.

# %%
#Q2.2 write your code here

# %% [markdown]
# **Q3**
#
# Q3.1) Using *thinkstats2* and *thinkplot* APIs, plot the Cumulative distribution function (Cdf)  of the *Protein* for two food groups: <br>
# i) Protein-plant <br>
# ii) Protein-animal <br>
#
#
# Q3.2) Using *thinkstats2* and *thinkplot* APIs, plot the Cumulative distribution function (Cdf)  of the *Fiber* for two food groups: <br>
# i) Protein-plant <br>
# ii) Protein-animal <br>
#
#
#
# Q3.3) What conclusions do you get from the plots?

# %%
#Q3.1 write your code here

# %%
#Q3.1 write your code here

# %%
# #Q3.3 write your answer here
